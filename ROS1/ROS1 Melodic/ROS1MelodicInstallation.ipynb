# %% [markdown]
# # ROS1 Melodic Installation Instructions (Ubuntu)
#
# Start by going to your application search and look for the "Software and Updates" application.
#
# Within this tab, ensure the following top four boxes:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# These boxes need to be enabled or else the repository for ROS cannot be cloned properly.
#
# Next, open a new terminal and enter the following command:
# ```
# sudo sh -c 'echo "deb http://packages.ros.org/ros/ubuntu $(lsb_release -sc) main" > /etc/apt/sources.list.d/ros-latest.list'
# ```
#
# Once the command is done running, enter the following commands to first install curl (if it isn't already installed):
# ```
# sudo apt intall curl
# ```
